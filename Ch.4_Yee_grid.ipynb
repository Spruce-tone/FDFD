# %%
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix
from typing import Union, Tuple, List
from lib.utils import *
from lib.mat_operator import *
from lib.PML import *
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Derivative matrix for 2D Yee grid

# %%
Ns = (3, 4)
Res = (0.2, 0.1)
bc = (BC.DBC, BC.DBC)
DeX, DeY, DhX, DhY = yeeder2d(Ns=Ns, Res=Res, bc=bc)

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 5))
axes = axes.ravel()

for idx, de in enumerate([DeX, DeY, DhX, DhY]):
    axes[idx].imshow(np.real(de.toarray()))

# %% [markdown]
# # Derivative matrix for 3D Yee grid

# %%
Ns = (2, 2, 2)
Res = (0.3, 0.2, 0.1)
bc = (BC.DBC, BC.DBC, BC.DBC)
DeX, DeY, DeZ, DhX, DhY, DhZ = yeeder3d(Ns=Ns, Res=Res, bc=bc)

# %%
fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(20, 5))
axes = axes.ravel()

for idx, de in enumerate([DeX, DeY, DeZ, DhX, DhY, DhZ]):
    axes[idx].imshow(np.real(de.toarray()))
